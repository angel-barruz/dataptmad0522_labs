# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %%
fig = plt.figure()
print(type(fig))
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
fig.number
# Out:
# 1

# %%
ax = plt.axes(arg = (0,0,1,1), projection = None, aspect = 1)
print(type(ax))
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1 (x,y)
fig, ax = plt.subplots(ncols = 1,
                       nrows = 1,
                       figsize= (11,5))
ax.bar(x, y)                  
plt.show();

# %%
# Method 1 (x,z)
fig, ax = plt.subplots(ncols = 1,
                       nrows = 1,
                       figsize= (11,5))
ax.bar(x, z)                  
plt.show();

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, axs = plt.subplots(ncols=2,
                        nrows=1,
                        figsize=(11,10))
axs[0].plot(x, y)                    
axs[0].set(ylim=[0, 100], xlabel='x', ylabel='y', title='x/y')
axs[1].scatter(x, z)                    
axs[1].set(xlabel='x', ylabel='y',  title='x/z')
plt.show();

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axs = plt.subplots(ncols=2,
                        nrows=1,
                        figsize=(20,15))
axs[0].plot(x, y)                    
axs[0].set(ylim=[0, 100], xlabel='x', ylabel='y', title='x/y')
axs[1].scatter(x, z)                    
axs[1].set(xlabel='x', ylabel='y',  title='x/z')
plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
e = np.arange(0,100)
set_xscale = x**2
set_yescale = e**x

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../data/fitbit2.csv')
fitbit.head(3)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# 0               1680  ...        0.403891    Friday           4.0
# 1               2248  ...        8.767545  Saturday           5.0
# 2               1719  ...        6.567891    Sunday           6.0
#
#    Work_or_Weekend  Hours Sleep Sleep efficiency  Yesterday_sleep  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
fitbit['Months_encoded'].median()
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,4))
ax = sns.barplot(data=fitbit, x='Months', y='Months_encoded')
plt.sca(ax)


# MEDIAN STEPS BY WORK_OR_WEEKEND
fitbit['Work_or_Weekend'].median()
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,4))
ax = sns.barplot(data=fitbit, x= 'Days',y='Work_or_Weekend')
ax.figure.sca(ax)
# Out:
# <AxesSubplot:xlabel='Days', ylabel='Work_or_Weekend'>

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
x_col = "Steps"
y_col = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]
data = pd.read_csv('../data/fitbit2.csv')

for y_col in y_columns:

    fig = plt.figure()
    ax = plt.axes(arg = (0,0,1,1), projection = None, aspect = 50)
    ax.scatter(data[x_col], data[y_col])
    ax.set_title("{} vs {}".format(y_col, x_col))
    plt.legend(["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 5>()
#       2 y_col = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]
#       3 data = pd.read_csv('../data/fitbit2.csv')
# ----> 5 for y_col in y_columns:
#       7     fig = plt.figure()
#       8     ax = plt.axes(arg = (0,0,1,1), projection = None, aspect = 50)
#
# NameError: name 'y_columns' is not defined

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(include='float64',).head(3)
# Out:
#    Survived   Age     Fare
# 0       0.0  22.0   7.2500
# 1       1.0  38.0  71.2833
# 2       1.0  26.0   7.9250

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include='int64',).head(3)
# Out:
#    PassengerId  Pclass  SibSp  Parch
# 0            1       3      1      0
# 1            2       1      1      0
# 2            3       3      0      0

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# figure object 

fig = plt.figure()
print(type(fig))
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
# axes object

ax = plt.axes(arg = (0,0,1,1), projection = None, aspect = 1)
print(type(ax))
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,6))Gender 
ax = sns.barplot(data=titanic)
# Out:
#   Input In [18]
#     fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,6))Gender
#                                                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,6))
ax = sns.barplot(data=titanic, y='Age', x='Gender')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
titanic['Age'].plot(kind='hist', bins=50, xlim=(1, 100), figsize=(12,6));

# %%
titanic['Age'].plot(kind='hist', bins=20, xlim=(1, 100), figsize=(12,6));

# %%
titanic['Age'].plot(kind='hist', bins=10, xlim=(1, 100), figsize=(12,6));

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here: Afecta porque el bins refleja el tamaño de la muestra en la distribución normal de la gráfica.
"""
# Out:
# '\nyour comments here: Afecta porque el bins refleja el tamaño de la muestra en la distribución normal de la gráfica.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
axs = sns.barplot(y="Age", data=titanic)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
len(titanic['PassengerId'].unique())
# Out:
# 1309

# %%
len(titanic['Gender'].unique())
# Out:
# 2

# %%
# abscissa axes 
def random_data_generator(array, low, high):
    return np.random.randint(low, high, len(array))

# abscissa axes 
x_cat = ['Male','Female']
x = np.random.randint(0, 100, 10)

# ordinate axes
y_cat = random_data_generator(x_cat, 500, 2000)
y = random_data_generator(x, 0, 1000)

# %%
# Method 1 - matplotlib
fig, ax = plt.subplots(ncols = 1,
                       nrows = 1,
                       figsize= (11,5))
ax.bar(x_cat,y_cat)                    
plt.show();

# %%
titanic_s = sns.load_dataset("titanic")
titanic_s.head(3)
# No entiendo porque los datos no coinciden con el DataFrame
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
# Method 2 - seaborn
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(11,5))
ax = sns.barplot(data=titanic_s, x='sex', y='fare')

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic_s.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic_s['pclass'].plot(kind='hist', bins=30, xlim = (1,3), figsize=(12,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic_h = titanic_s['age'].plot(kind='hist', bins=30, xlim=(1, 90), figsize=(12,6))
# Out:
# 89

# %%
titanic_h = titanic_s['age'].plot(kind='hist', bins=30, xlim=(1, 90), figsize=(12,6))

# %%
"""
your comments here
histograma
"""
# Out:
# '\nyour comments here\nhistograma\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
La mayotía de pasajeros, tenían un rango de edad entre 20,22 y 27 años
"""
# Out:
# '\nyour comments here\nLa mayotía de pasajeros, tenían un rango de edad entre 20,22 y 27 años\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.displot(titanic_s['age'], kind = ('hist'), kde = True)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
La distribución es normal
"""
# Out:
# '\nyour comments here\nLa distribución es normal\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
len(titanic['Fare'].unique())
# Out:
# 281

# %%
def random_data_generator(array, low, high):
    return np.random.randint(low, high, len(array))

# abscissa axes 
Age = ['10', '20', '30', '40', '50', '60', '70', '80', '90']
x = np.random.randint(0, 100, 10)

# ordinate axes
y_cat = random_data_generator(Age, 100, 1000)
y_cat_mean = y_cat.mean()
y = random_data_generator(Age, 0, 1000)

# %%
# Method 1 - matplotlib
fig, ax = plt.subplots(ncols = 1,
                       nrows = 1,
                       figsize= (11,5))
ax.bar(Age,y_cat)                    
plt.show();

# %%
titanic_s = sns.load_dataset("titanic")
titanic_s.head(3)
# No entiendo porque los datos no coinciden con el DataFrame
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic_s.plot(x='age', y='fare', kind='hist', figsize=(12,6), ylim=(0,1000), xlim=(0,90))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
titanic_matrix = titanic_s.corr()
titanic_matrix
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
sibsp VS survived, sibsp VA pclass, parch VS survived
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,6))
ax = sns.barplot(data=titanic_s, x='pclass', y='age')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g=sns.FacetGrid(titanic, col="Age",  row="Gender")
#g.map(sns.scatterplot, "total_bill", "tip")
g
